# %%
import pandas as pd 

df = pd.read_excel("../data/Data_FINAL_PROJECT.xlsx")

# %%
#remove mapped_country because it is useless now 

df = df.drop(columns=['Mapped_Country'])

df = df.dropna()

df.columns
# Out:
# Index(['Country', 'Exports_2014', 'Exports_2015', 'Exports_2016',
#        'Exports_2017', 'Exports_2018', 'Exports_2019', 'Exports_2020',
#        'Exports_2021', 'Exports_2022', 'Imports_2014', 'Imports_2015',
#        'Imports_2016', 'Imports_2017', 'Imports_2018', 'Imports_2019',
#        'Imports_2020', 'Imports_2021', 'Imports_2022', 'Trade_balance_2014',
#        'Trade_balance_2015', 'Trade_balance_2016', 'Trade_balance_2017',
#        'Trade_balance_2018', 'Trade_balance_2019', 'Trade_balance_2020',
#        'Trade_balance_2021', 'Trade_balance_2022', 'GDP_2014', 'GDP_2015',
#        'GDP_2016', 'GDP_2017', 'GDP_2018', 'GDP_2019', 'GDP_2020', 'GDP_2021',
#        'GDP_2022', 'Inflation_2014', 'Inflation_2015', 'Inflation_2016',
#        'Inflation_2017', 'Inflation_2018', 'Inflation_2019', 'Inflation_2020',
#        'Inflation_2021', 'Inflation_2022'],
#       dtype='object')

# %%
#convert all columns to numeric EXCEPT COUNTRY
df = df.drop(index=0)

df = df.dropna()

for col in df:
    if col !='Country':
        
        df[col] = pd.to_numeric(df[col], errors='coerce')
        

df.head()
# Out:
#                  Country   Exports_2014   Exports_2015   Exports_2016  \
# 1             Bangladesh   29230.005539   30029.299084   30903.584025
# 2      Brunei Darussalam    2996.122479    2408.143278    1401.634799
# 3               Cambodia   11536.022289   11986.376973   11832.566629
# 4  China, P.R.: Mainland  513669.729147  377365.110265  359592.786488
# 5          Fiji, Rep. of     527.634375     547.539494     675.485558
#
#     Exports_2017   Exports_2018   Exports_2019   Exports_2020   Exports_2021  \
# 1   35501.954340   41062.647812   41918.996690   36957.276700   59949.066008
# 2    1456.480639    2459.303028    2414.828419    2315.852901    3637.447446
# 3   13858.214700   18567.832293   21209.647772   19824.908218   25133.044730
# 4  458784.019380  584016.843584  571162.475142  548652.657144  738139.333222
# 5     627.371933     731.277077     584.014363     502.129618     674.672129
#
#     Exports_2022  ...      GDP_2022  Inflation_2014  Inflation_2015  \
# ...

# %%
rows_with_nulls = df[df.isnull().any(axis=1)]

# Display the first few rows that contain null values
rows_with_nulls.head()
# Out:
# Empty DataFrame
# Columns: [Country, Exports_2014, Exports_2015, Exports_2016, Exports_2017, Exports_2018, Exports_2019, Exports_2020, Exports_2021, Exports_2022, Imports_2014, Imports_2015, Imports_2016, Imports_2017, Imports_2018, Imports_2019, Imports_2020, Imports_2021, Imports_2022, Trade_balance_2014, Trade_balance_2015, Trade_balance_2016, Trade_balance_2017, Trade_balance_2018, Trade_balance_2019, Trade_balance_2020, Trade_balance_2021, Trade_balance_2022, GDP_2014, GDP_2015, GDP_2016, GDP_2017, GDP_2018, GDP_2019, GDP_2020, GDP_2021, GDP_2022, Inflation_2014, Inflation_2015, Inflation_2016, Inflation_2017, Inflation_2018, Inflation_2019, Inflation_2020, Inflation_2021, Inflation_2022]
# Index: []
#
# [0 rows x 46 columns]

# %%
df_cleaned = df.dropna()

rows_with_nulls = df_cleaned[df_cleaned.isnull().any(axis=1)]

rows_with_nulls

df_cleaned.head(50)
# Out:
#                             Country   Exports_2014   Exports_2015  \
# 1                        Bangladesh   29230.005539   30029.299084
# 2                 Brunei Darussalam    2996.122479    2408.143278
# 3                          Cambodia   11536.022289   11986.376973
# 4             China, P.R.: Mainland  513669.729147  377365.110265
# 5                     Fiji, Rep. of     527.634375     547.539494
# 6                             India  293233.544055  226257.676511
# 7                         Indonesia   88948.937218   70527.042987
# 8            Lao People's Dem. Rep.    6463.327001    6083.421136
# 9                          Malaysia   99015.282032   86106.833228
# 10                         Maldives    1153.706879    1022.755842
# 11  Micronesia, Federated States of      72.897523      71.913627
# 12                         Mongolia    3985.456015    2942.373403
# 13                            Nepal    7399.172073    4737.413303
# ...

# %%
#Convert PIB into Millions USD 

for column in df_cleaned:
    if column.startswith('GDP_'):
        df_cleaned[column] = df_cleaned[column].astype(float) / 1e6

# %%
#Create Trade Openness / Openness Ratio variable

for year in range(2014, 2023):
    export_column = f'Exports_{year}'
    import_column = f'Imports_{year}'
    gdp_column = f'GDP_{year}'
    openness_column = f'Openness_{year}'

    df_cleaned[export_column] = df_cleaned[export_column].astype(float)
    df_cleaned[import_column] = df_cleaned[import_column].astype(float)

    #Trade Openness formula
    df_cleaned[openness_column] = (df_cleaned[export_column] + df_cleaned[import_column]) / 2 / df_cleaned[gdp_column] * 100

# %%
#drop inflation 

columns_to_drop = [col for col in df_cleaned.columns if 'Inflation' in col]
df_cleaned = df_cleaned.drop(columns=columns_to_drop)

# %%
print(df_cleaned['Openness_2014'])
# Out:
# 1       9.999221
# 2      17.108577
# 3      42.466432
# 4       5.960653
# 5       8.593720
#          ...
# 110    26.270987
# 111    16.213260
# 112     9.476624
# 113    20.726020
# 114    14.917885
# Name: Openness_2014, Length: 114, dtype: float64

# %%
# Categorizing countries by continent
Asia_Countries = df_cleaned.iloc[0:20]
Asia_Countries = Asia_Countries[Asia_Countries.Country != 'China, P.R.: Mainland']

Asia_Countries.head(22)
# Out:
#                             Country   Exports_2014   Exports_2015  \
# 1                        Bangladesh   29230.005539   30029.299084
# 2                 Brunei Darussalam    2996.122479    2408.143278
# 3                          Cambodia   11536.022289   11986.376973
# 5                     Fiji, Rep. of     527.634375     547.539494
# 6                             India  293233.544055  226257.676511
# 7                         Indonesia   88948.937218   70527.042987
# 8            Lao People's Dem. Rep.    6463.327001    6083.421136
# 9                          Malaysia   99015.282032   86106.833228
# 10                         Maldives    1153.706879    1022.755842
# 11  Micronesia, Federated States of      72.897523      71.913627
# 12                         Mongolia    3985.456015    2942.373403
# 13                            Nepal    7399.172073    4737.413303
# 14                      Philippines   49174.226834   48345.139619
# ...

# %%
Europe_countries = df_cleaned.iloc[20:34]

Europe_countries.head(15)
# Out:
#                          Country   Exports_2014  Exports_2015  Exports_2016  \
# 21                       Albania    1550.684438   1471.774970   1624.400938
# 22              Belarus, Rep. of   26173.634447  18975.785011  18539.704177
# 23        Bosnia and Herzegovina    3501.699821   2652.095746   2637.789037
# 24                      Bulgaria   13181.224349  12021.407333  13291.706584
# 25                       Hungary   26087.589053  21889.614161  22367.927615
# 26               Kosovo, Rep. of    1262.531801   1034.688638   1145.721680
# 27              Moldova, Rep. of    4733.112044   3206.119880   3084.314814
# 28                    Montenegro    1508.407815   1327.957268   1356.434565
# 29  North Macedonia, Republic of    2235.602765   2069.327205   2160.316426
# 30               Poland, Rep. of   52525.927666  44729.131799  46298.332824
# 31                       Romania   27372.535229  24133.825436  24997.059895
# ...

# %%
middle_east_central_asia_countries = df_cleaned.iloc[34:57]

middle_east_central_asia_countries.head(24)
# Out:
#                         Country   Exports_2014   Exports_2015   Exports_2016  \
# 35                      Algeria   20756.123822   19432.028414   21349.480843
# 36             Armenia, Rep. of    2283.441925    1889.080869    1723.594089
# 37          Azerbaijan, Rep. of    9631.518821    6553.144156    4542.387815
# 38          Bahrain, Kingdom of   16299.394249   10716.136559    9265.244871
# 39                     Djibouti    4362.804964    4247.167554    4478.201193
# 40          Egypt, Arab Rep. of   44833.365899   40679.358512   39498.000396
# 41                      Georgia    6371.393143    5383.246747    5407.004512
# 42                         Iraq   31880.455776   26406.365284   22525.208545
# 43                       Jordan   15686.096781   12173.833857   10510.952764
# 44                       Kuwait   15631.427760   14633.534647   13152.491369
# 45                  Kyrgyz Rep.    8645.647699    6760.784121    7845.875541
# ...

# %%
sub_saharan_africa_countries =df_cleaned.iloc[57:91] 

sub_saharan_africa_countries.head(35)
# Out:
#                                 Country  Exports_2014  Exports_2015  \
# 58                                Benin   6463.367729   5112.724040
# 59                             Botswana   6128.255905   5609.635585
# 60                         Burkina Faso   2034.519468   1551.551663
# 61                              Burundi    350.779022    265.441520
# 62                             Cameroon   4725.154602   3809.781919
# 63                 Central African Rep.    110.407391    125.680993
# 64                                 Chad    645.186274    427.716654
# 65                       Congo, Rep. of   3787.816307   2569.481219
# 66                        Côte d'Ivoire   6367.004431   5741.064051
# 67           Equatorial Guinea, Rep. of    949.623736    614.941541
# 68                                Gabon   2045.985671   1764.912411
# 69                          Gambia, The    894.896027    739.135084
# 70                                Ghana  10980.241885  10556.972244
# ...

# %%
western_hemisphere_countries =df_cleaned.iloc[91:114] 

western_hemisphere_countries.head(23)
# Out:
#                  Country   Exports_2014  Exports_2015  Exports_2016  \
# 92   Antigua and Barbuda     639.494224    312.665067    401.824439
# 93          Bahamas, The    3464.844049   4212.668050   1682.287335
# 94               Bolivia    6210.470534   5252.533893   5789.972995
# 95                Brazil  112917.047970  78544.784437  63598.955234
# 96                 Chile   32765.558016  29081.412664  28406.419836
# 97              Colombia   23817.976163  20314.929856  18937.380116
# 98            Costa Rica    4772.501032   4867.409535   5216.178952
# 99        Dominican Rep.    5427.210600   5254.826920   5385.614783
# 100              Ecuador   10322.487544   8232.765958   6970.335941
# 101          El Salvador    3922.697740   4032.359157   3968.190714
# 102              Grenada     160.434261    136.991412    164.763099
# 103            Guatemala    6687.235545   6984.635386   6642.731851
# 104               Guyana     870.131442    602.007930    612.393522
# ...

# %%
import matplotlib.pyplot as plt

regional_data = {
    'Asia': Asia_Countries,
    'Sub-Saharan Africa': sub_saharan_africa_countries,
    'Middle East and Central Asia': middle_east_central_asia_countries,
    'Western Hemisphere': western_hemisphere_countries,
    'Europe': Europe_countries
}

# Définition des années et des colonnes correspondantes pour les exportations, importations, PIB et degré d'ouverture
years = ['2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022']
export_columns = [f'Exports_{year}' for year in years]
import_columns = [f'Imports_{year}' for year in years]
gdp_columns = [f'GDP_{year}' for year in years]
openness_columns = [f'Openness_{year}' for year in years]

# Création des graphiques
fig, axes = plt.subplots(nrows=5, ncols=3, figsize=(14, 18), constrained_layout=True)

# Boucle pour chaque région et création des graphiques
for i, (region_name, region_df) in enumerate(regional_data.items()):
    # Tracer les données d'exportation et d'importation
    axes[i, 0].plot(years, region_df[export_columns].mean() / 1e6, label='Exports', marker='o', color='blue')
    axes[i, 0].plot(years, region_df[import_columns].mean() / 1e6, label='Imports', marker='o', color='orange')
    axes[i, 0].set_title(f'Trade for {region_name}')
    axes[i, 0].set_xlabel('Year')
    axes[i, 0].set_ylabel('US $ in millions')
    axes[i, 0].legend()
    axes[i, 0].grid(True)
    
    # Tracer les données de PIB
    axes[i, 1].plot(years, region_df[gdp_columns].mean() / 1e6, label='GDP', marker='x', color='green')
    axes[i, 1].set_title(f'GDP for {region_name}')
    axes[i, 1].set_xlabel('Year')
    axes[i, 1].set_ylabel('US $ in millions')
    axes[i, 1].legend()
    axes[i, 1].grid(True)
    
    # Tracer les données de degré d'ouverture
    axes[i, 2].plot(years, region_df[openness_columns].mean(), label='Openness', marker='s', color='purple')
    axes[i, 2].set_title(f'Openness for {region_name}')
    axes[i, 2].set_xlabel('Year')
    axes[i, 2].set_ylabel('Openness (%)')
    axes[i, 2].legend()
    axes[i, 2].grid(True)

# Ajustement de la mise en page pour éviter le chevauchement
plt.tight_layout()

# Afficher le graphique
plt.show()
# Out:
# C:\Users\Manjaka\AppData\Local\Temp\ipykernel_20280\615410756.py:49: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %%
import pandas as pd

# Liste de DataFrames représentant chaque groupe de pays
Countries_group = [
    Europe_countries,
    middle_east_central_asia_countries,
    sub_saharan_africa_countries,
    western_hemisphere_countries,
    Asia_Countries
]

# Noms des groupes pour l'index du DataFrame final
group_names = [
    "Europe_countries",
    "middle_east_central_asia_countries",
    "sub_saharan_africa_countries",
    "western_hemisphere_countries",
    "Asia_Countries"
]

# Création d'un DataFrame vide pour stocker les moyennes de chaque groupe de pays
averages_by_group = pd.DataFrame()

# Boucle à travers les DataFrames de chaque groupe de pays
for i, group_df in enumerate(Countries_group):
    # Calcul des moyennes par année de 2014 à 2022
    averages = {}
    for year in range(2014, 2023):
        year_columns = [f'{col}_{year}' for col in ['GDP', 'Exports', 'Imports', 'Openness']]
        averages[f'Avg_GDP_{year}'] = group_df[year_columns[0]].mean()
        averages[f'Avg_Exports_{year}'] = group_df[year_columns[1]].mean()
        averages[f'Avg_Imports_{year}'] = group_df[year_columns[2]].mean()
        averages[f'Avg_Openness_{year}'] = group_df[year_columns[3]].mean()
    
    # Créer un DataFrame avec les moyennes pour ce groupe de pays
    df_averages_group = pd.DataFrame(averages, index=[group_names[i]])
    
    # Ajouter ce DataFrame au tableau général
    averages_by_group = pd.concat([averages_by_group, df_averages_group])

# Afficher le tableau des moyennes par groupe de pays
print(averages_by_group)
# Out:
#                                      Avg_GDP_2014  Avg_Exports_2014  \
# Europe_countries                    157108.444345      22373.072959
# middle_east_central_asia_countries  140168.836123      22978.924024
# sub_saharan_africa_countries         45310.244043       6716.996040
# western_hemisphere_countries        226375.189368      14781.460229
# Asia_Countries                      239763.761907      42671.123594
#
#                                     Avg_Imports_2014  Avg_Openness_2014  \
# Europe_countries                        18930.542367          18.187483
# middle_east_central_asia_countries      23751.189256          22.653456
# sub_saharan_africa_countries             6232.585232          19.576901
# western_hemisphere_countries            15690.895007          16.025927
# Asia_Countries                          31926.523404          23.344807
#
#                                      Avg_GDP_2015  Avg_Exports_2015  \
# ...

# %%
df_cleaned.columns

# %%
import seaborn as sns

gdp_data = averages_by_group.filter(like='Avg_GDP').rename(lambda x: x.split('_')[-1], axis='columns')

# Creating the heatmap for GDP
plt.figure(figsize=(12, 6))
sns.heatmap(gdp_data, annot=False, fmt=".1f", linewidths=.5, cmap="YlGnBu")
plt.title('Average GDP by Country Group (2014-2022)')
plt.xlabel('Year')
plt.ylabel('Country Group')
plt.show()

# %%
openness_data = averages_by_group.filter(like='Avg_Openness').rename(lambda x: x.split('_')[-1], axis='columns')

# Création de la heatmap pour le degré d'ouverture
plt.figure(figsize=(12, 6))
sns.heatmap(openness_data, annot=False, fmt=".1f", linewidths=.5, cmap="YlOrRd")
plt.title('Average Openness by Country Group (2014-2022)')
plt.xlabel('Year')
plt.ylabel('Country Group')
plt.show()

# %%
# Extracting Exports data
exports_data = averages_by_group.filter(like='Avg_Exports').rename(lambda x: x.split('_')[-1], axis='columns')

# Creating the heatmap for Exports
plt.figure(figsize=(12, 6))
sns.heatmap(exports_data, annot=False, fmt=".1f", linewidths=.5, cmap="BuPu")
plt.title('Average Exports by Country Group (2014-2022)')
plt.xlabel('Year')
plt.ylabel('Country Group')
plt.show()

# %%
# Extracting Imports data
imports_data = averages_by_group.filter(like='Avg_Imports').rename(lambda x: x.split('_')[-1], axis='columns')

# Creating the heatmap for Imports
plt.figure(figsize=(12, 6))
sns.heatmap(imports_data, annot=False, fmt=".1f", linewidths=.5, cmap="RdPu")
plt.title('Average Imports by Country Group (2014-2022)')
plt.xlabel('Year')
plt.ylabel('Country Group')
plt.show()

# %%
import matplotlib.pyplot as plt

# Exemple de données
x = df_cleaned['Exports_2014']  # Remplacez 'Exports' par le nom de votre variable indépendante
y = df_cleaned['GDP_2014']      # Remplacez 'GDP' par le nom de votre variable dépendante

# Création du graphique de dispersion
plt.scatter(x, y)
plt.xlabel('Exports')
plt.ylabel('GDP')
plt.title('Scatter Plot of GDP vs Exports')
plt.show()

# %%
import pandas as pd

# Supposons que votre DataFrame s'appelle df et qu'il contient des colonnes 'Country' et 'GDP'
# Vous avez déjà calculé l'IQR et les bornes pour les valeurs aberrantes du PIB.

# Calculez le premier et le troisième quartile (Q1 et Q3)
Q1 = df_cleaned['GDP_2014'].quantile(0.25)
Q3 = df_cleaned['GDP_2014'].quantile(0.75)
IQR = Q3 - Q1

# Définissez les bornes pour les valeurs aberrantes
borne_inf = Q1 - 1.5 * IQR
borne_sup = Q3 + 1.5 * IQR

# Trouvez les lignes où la valeur du PIB est une valeur aberrante
outliers = df_cleaned[(df_cleaned['GDP_2014'] < borne_inf) | (df['GDP_2014'] > borne_sup)]

# Imprimez les pays associés aux valeurs aberrantes
print(outliers['Country'])

# %%
import pandas as pd
import statsmodels.api as sm

# Charger vos données
# df = pd.read_csv('chemin_vers_votre_fichier.csv')

# Régression pour l'année 2014
X = df_cleaned[['Exports_2014', 'Imports_2014', 'Openness_2014']]
# Si vous voulez utiliser le solde commercial et l'ouverture économique :
# X = df[['Trade_balance_2014', 'Openness_2014']]

X = sm.add_constant(X) # Ajouter une constante au modèle
y = df_cleaned['GDP_2014']

model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               GDP_2014   R-squared:                       0.921
# Model:                            OLS   Adj. R-squared:                  0.919
# Method:                 Least Squares   F-statistic:                     428.4
# Date:                Sat, 02 Dec 2023   Prob (F-statistic):           1.69e-60
# Time:                        13:18:05   Log-Likelihood:                -1594.7
# No. Observations:                 114   AIC:                             3197.
# Df Residuals:                     110   BIC:                             3208.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const          9869.8575   4.87e+04      0.203      0.840   -8.66e+04    1.06e+05
# ...

# %%
def perform_regression(df_region, year):
    # Vérifiez si df_region est vide
    if df_region.empty:
        print(f"Aucune donnée disponible pour la région spécifiée en {year}")
        return

    # Préparation des données pour la régression
    X = df_region[[f'Exports_{year}']]
    X = sm.add_constant(X)
    y = df_region[f'GDP_{year}']

    # Vérifiez si X ou y contient des valeurs manquantes
    if X.dropna().empty or y.dropna().empty:
        print(f"Données insuffisantes pour la régression en {year}")
        return

    # Construction et affichage du modèle de régression
    model = sm.OLS(y, X).fit()
    print(f"Résultats pour l'année {year} dans la région spécifiée:")
    print(model.summary())
    print("\n")

# Effectuer la régression pour chaque année pour les pays européens
Europe_countries = df_cleaned.iloc[20:34]  # Données pour les pays européens
Asia_Countries = df_cleaned.iloc[0:20]
middle_east_central_asia_countries = df_cleaned.iloc[34:57]
sub_saharan_africa_countries =df_cleaned.iloc[57:91] 
western_hemisphere_countries =df_cleaned.iloc[91:114] 
for year in range(2014, 2023):
    print(f"--- Analyse pour l'Asie en l'année {year} ---")
    perform_regression(Asia_Countries, year)

    print(f"--- Analyse pour l'Europe en l'année {year} ---")
    perform_regression(Europe_countries, year)
    
    print(f"--- Analyse pour le middle east en l'année {year} ---")
    perform_regression(middle_east_central_asia_countries, year)

    print(f"--- Analyse pour l'Afrique en l'année {year} ---")
    perform_regression(sub_saharan_africa_countries, year)

    print(f"--- Analyse pour le western en l'année {year} ---")
    perform_regression(western_hemisphere_countries, year)
# Out:
# --- Analyse pour l'Asie en l'année 2014 ---
# Résultats pour l'année 2014 dans la région spécifiée:
#                             OLS Regression Results
# ...
# Dep. Variable:               GDP_2014   R-squared:                       0.851
# Model:                            OLS   Adj. R-squared:                  0.843
# Method:                 Least Squares   F-statistic:                     103.2
# Date:                Sat, 02 Dec 2023   Prob (F-statistic):           7.03e-09
# Time:                        13:18:05   Log-Likelihood:                -302.09
# No. Observations:                  20   AIC:                             608.2
# Df Residuals:                      18   BIC:                             610.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## ASIA COUNTRIES

# %% [markdown]
# ## Europe countries

# %% [markdown]
# ## Middle east central asia countries

# %% [markdown]
# ## Sub-saharan Africa Countries

# %% [markdown]
# ## Western hemisphere

# %% [markdown]
# CLUSTERING

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# Charger les données
# df = pd.read_csv('votre_fichier.csv')

# Sélectionner et normaliser les variables pour chaque année
scaler = StandardScaler()
df_normalized = df_cleaned.copy()
for year in range(2014, 2023):
    df_normalized[[f'GDP_{year}', f'Trade_Balance_{year}', f'Exports_{year}', f'Imports_{year}']] = \
        scaler.fit_transform(df[[f'GDP_{year}', f'Trade_balance_{year}', f'Exports_{year}', f'Imports_{year}']])

# Appliquer K-means
kmeans = KMeans(n_clusters=3, random_state=0).fit(df_normalized.drop(['Country'], axis=1))
df['Cluster'] = kmeans.labels_

# Visualisation avec PCA
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(df_normalized.drop(['Country'], axis=1))
principalDf = pd.DataFrame(data=principalComponents, columns=['PC1', 'PC2'])
principalDf['Cluster'] = df['Cluster']

# Tracer le résultat
plt.figure(figsize=(8,6))
plt.scatter(principalDf['PC1'], principalDf['PC2'], c=principalDf['Cluster'])
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('2D PCA')
plt.show()

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

def check_multicollinearity(X):
    # Cette fonction calcule le VIF pour chaque variable explicative
    vif_data = pd.DataFrame()
    vif_data["feature"] = X.columns
    vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
    return vif_data

def perform_regression(df_region, year):
    # Vérifiez si df_region est vide
    if df_region.empty:
        print(f"Aucune donnée disponible pour la région spécifiée en {year}")
        return

    # Préparation des données pour la régression
    X = df_region[[f'Exports_{year}',f'Openness_{year}']]
    X = sm.add_constant(X)
    y = df_region[f'GDP_{year}']

    # Vérifiez si X ou y contient des valeurs manquantes
    if X.isnull().values.any() or y.isnull().values.any():
        print(f"Données insuffisantes pour la régression en {year}")
        return

    # Vérifier la multicolinéarité
    vif_data = check_multicollinearity(X.drop(columns=['const'])) # exclure la constante du calcul du VIF
    print("VIF pour chaque variable:")
    print(vif_data)

    # Gestion de la multicolinéarité
    while vif_data['VIF'].max() > 10:  # Seuil de VIF
        # Retirez la variable avec le VIF le plus élevé
        highest_vif = vif_data.sort_values('VIF', ascending=False).iloc[0]
        X = X.drop(columns=[highest_vif['feature']])
        vif_data = check_multicollinearity(X.drop(columns=['const']))
        print("VIF mis à jour pour chaque variable:")
        print(vif_data)
    # Construction et affichage du modèle de régression
    model = sm.OLS(y, X).fit()
    print(f"Résultats pour l'année {year} dans la région spécifiée:")
    print(model.summary())
    print("\n")

# Exemple d'utilisation de la fonction
# Notez que vous devez définir 'df_cleaned' avec vos données avant d'utiliser ce code
Europe_countries = df_cleaned.iloc[20:34]  # Données pour les pays européens
Asia_Countries = df_cleaned.iloc[0:20]
middle_east_central_asia_countries = df_cleaned.iloc[34:57]
sub_saharan_africa_countries =df_cleaned.iloc[57:91] 
western_hemisphere_countries =df_cleaned.iloc[91:114] 
for year in range(2014, 2023):
    print(f"--- Analyse pour l'Asie en l'année {year} ---")
    perform_regression(Asia_Countries, year)

    print(f"--- Analyse pour l'Europe en l'année {year} ---")
    perform_regression(Europe_countries, year)
    
    print(f"--- Analyse pour le middle east en l'année {year} ---")
    perform_regression(middle_east_central_asia_countries, year)

    print(f"--- Analyse pour l'Afrique en l'année {year} ---")
    perform_regression(sub_saharan_africa_countries, year)

    print(f"--- Analyse pour le western en l'année {year} ---")
    perform_regression(western_hemisphere_countries, year)

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

def check_multicollinearity(X):
    # Cette fonction calcule le VIF pour chaque variable explicative
    vif_data = pd.DataFrame()
    vif_data["feature"] = X.columns
    vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
    return vif_data

def perform_regression(df_region, year):
    # Vérifiez si df_region est vide
    if df_region.empty:
        print(f"Aucune donnée disponible pour la région spécifiée en {year}")
        return

    # Préparation des données pour la régression
    X = df_region[[f'Imports_{year}', f'Inflation_{year}',f'Openness_{year}']]
    X = sm.add_constant(X)
    y = df_region[f'GDP_{year}']

    # Vérifiez si X ou y contient des valeurs manquantes
    if X.isnull().values.any() or y.isnull().values.any():
        print(f"Données insuffisantes pour la régression en {year}")
        return

    # Vérifier la multicolinéarité
    vif_data = check_multicollinearity(X.drop(columns=['const'])) # exclure la constante du calcul du VIF
    print("VIF pour chaque variable:")
    print(vif_data)

    # Gestion de la multicolinéarité
    while vif_data['VIF'].max() > 10:  # Seuil de VIF
        # Retirez la variable avec le VIF le plus élevé
        highest_vif = vif_data.sort_values('VIF', ascending=False).iloc[0]
        X = X.drop(columns=[highest_vif['feature']])
        vif_data = check_multicollinearity(X.drop(columns=['const']))
        print("VIF mis à jour pour chaque variable:")
        print(vif_data)
    # Construction et affichage du modèle de régression
    model = sm.OLS(y, X).fit()
    print(f"Résultats pour l'année {year} dans la région spécifiée:")
    print(model.summary())
    print("\n")

# Exemple d'utilisation de la fonction
# Notez que vous devez définir 'df_cleaned' avec vos données avant d'utiliser ce code
Europe_countries = df_cleaned.iloc[20:34]  # Données pour les pays européens
Asia_Countries = df_cleaned.iloc[0:20]
middle_east_central_asia_countries = df_cleaned.iloc[34:57]
sub_saharan_africa_countries =df_cleaned.iloc[57:91] 
western_hemisphere_countries =df_cleaned.iloc[91:114] 
for year in range(2014, 2023):
    print(f"--- Analyse pour l'Asie en l'année {year} ---")
    perform_regression(Asia_Countries, year)

    print(f"--- Analyse pour l'Europe en l'année {year} ---")
    perform_regression(Europe_countries, year)
    
    print(f"--- Analyse pour le middle east en l'année {year} ---")
    perform_regression(middle_east_central_asia_countries, year)

    print(f"--- Analyse pour l'Afrique en l'année {year} ---")
    perform_regression(sub_saharan_africa_countries, year)

    print(f"--- Analyse pour le western en l'année {year} ---")
    perform_regression(western_hemisphere_countries, year)

# %%
def perform_regression(df_region, year):
    # Vérifiez si df_region est vide
    if df_region.empty:
        print(f"Aucune donnée disponible pour la région spécifiée en {year}")
        return

    # Préparation des données pour la régression
    X = df_region[[f'Exports_{year}']]
    X = sm.add_constant(X)
    y = df_region[f'GDP_{year}']

    # Vérifiez si X ou y contient des valeurs manquantes
    if X.dropna().empty or y.dropna().empty:
        print(f"Données insuffisantes pour la régression en {year}")
        return

    # Construction et affichage du modèle de régression
    model = sm.OLS(y, X).fit()
    print(f"Résultats pour l'année {year} dans la région spécifiée:")
    print(model.summary())
    print("\n")

# Effectuer la régression pour chaque année pour les pays européens
Europe_countries = df_cleaned.iloc[20:34]  # Données pour les pays européens
Asia_Countries = df_cleaned.iloc[0:20]
middle_east_central_asia_countries = df_cleaned.iloc[34:57]
sub_saharan_africa_countries =df_cleaned.iloc[57:91] 
western_hemisphere_countries =df_cleaned.iloc[91:114] 
for year in range(2014, 2023):
    print(f"--- Analyse pour l'Asie en l'année {year} ---")
    perform_regression(Asia_Countries, year)

    print(f"--- Analyse pour l'Europe en l'année {year} ---")
    perform_regression(Europe_countries, year)
    
    print(f"--- Analyse pour le middle east en l'année {year} ---")
    perform_regression(middle_east_central_asia_countries, year)

    print(f"--- Analyse pour l'Afrique en l'année {year} ---")
    perform_regression(sub_saharan_africa_countries, year)

    print(f"--- Analyse pour le western en l'année {year} ---")
    perform_regression(western_hemisphere_countries, year)

# %%
df_cleaned.to_csv('../data/Final_Data_test.csv', index=False)

# %%
pip install plotly ipywidgets

# %%
import plotly.graph_objects as go
import ipywidgets as widgets

# Exemple de données (remplacez ceci par vos vraies données)
regional_data = {
    'Asia': Asia_Countries,  # Remplacez par vos DataFrames
    'Sub-Saharan Africa': sub_saharan_africa_countries,
    'Middle East and Central Asia': middle_east_central_asia_countries,
    'Western Hemisphere': western_hemisphere_countries,
    'Europe': Europe_countries
}

# Définition des années et des colonnes correspondantes pour les variables
years = ['2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022']
export_columns = [f'Exports_{year}' for year in years]
import_columns = [f'Imports_{year}' for year in years]
gdp_columns = [f'GDP_{year}' for year in years]
openness_columns = [f'Openness_{year}' for year in years]

# Widgets pour la sélection du continent et de la variable
continent_selector = widgets.Dropdown(
    options=['Asia', 'Sub-Saharan Africa', 'Middle East and Central Asia', 'Western Hemisphere', 'Europe'],
    value='Asia',
    description='Continent:',
)

variable_selector = widgets.Dropdown(
    options=['Exports', 'Imports', 'GDP', 'Openness'],
    value='Exports',
    description='Variable:',
)

# Fonction pour mettre à jour le graphique
def update_graph(continent, variable):
    region_df = regional_data[continent]
    if variable == 'Exports':
        y_data = region_df[export_columns].mean() / 1e6
    elif variable == 'Imports':
        y_data = region_df[import_columns].mean() / 1e6
    elif variable == 'GDP':
        y_data = region_df[gdp_columns].mean() / 1e6
    else:  # Openness
        y_data = region_df[openness_columns].mean()

    fig = go.Figure(data=go.Scatter(x=years, y=y_data, mode='lines+markers'))
    fig.update_layout(title=f'{variable} for {continent}', xaxis_title='Year', yaxis_title=variable)
    fig.show()

# Affichage interactif
widgets.interactive(update_graph, continent=continent_selector, variable=variable_selector)

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

def check_multicollinearity(X):
    # Cette fonction calcule le VIF pour chaque variable explicative
    vif_data = pd.DataFrame()
    vif_data["feature"] = X.columns
    vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
    return vif_data

def perform_regression(df_region, year):
    # Vérifiez si df_region est vide
    if df_region.empty:
        print(f"Aucune donnée disponible pour la région spécifiée en {year}")
        return

    # Préparation des données pour la régression
    X = df_region[[f'Exports_{year}', f'Inflation_{year}']]
    X = sm.add_constant(X)
    y = df_region[f'GDP_{year}']

    # Vérifiez si X ou y contient des valeurs manquantes
    if X.isnull().values.any() or y.isnull().values.any():
        print(f"Données insuffisantes pour la régression en {year}")
        return

    # Vérifier la multicolinéarité
    vif_data = check_multicollinearity(X.drop(columns=['const'])) # exclure la constante du calcul du VIF
    print("VIF pour chaque variable:")
    print(vif_data)

    # Gestion de la multicolinéarité
    while vif_data['VIF'].max() > 10:  # Seuil de VIF
        # Retirez la variable avec le VIF le plus élevé
        highest_vif = vif_data.sort_values('VIF', ascending=False).iloc[0]
        X = X.drop(columns=[highest_vif['feature']])
        vif_data = check_multicollinearity(X.drop(columns=['const']))
        print("VIF mis à jour pour chaque variable:")
        print(vif_data)
    # Construction et affichage du modèle de régression
    model = sm.OLS(y, X).fit()
    print(f"Résultats pour l'année {year} dans la région spécifiée:")
    print(model.summary())
    print("\n")

# Exemple d'utilisation de la fonction
# Notez que vous devez définir 'df_cleaned' avec vos données avant d'utiliser ce code
Europe_countries = df_cleaned.iloc[20:34]  # Données pour les pays européens
Asia_Countries = df_cleaned.iloc[0:20]
middle_east_central_asia_countries = df_cleaned.iloc[34:57]
sub_saharan_africa_countries =df_cleaned.iloc[57:91] 
western_hemisphere_countries =df_cleaned.iloc[91:114] 
for year in range(2014, 2023):
    print(f"--- Analyse pour l'Asie en l'année {year} ---")
    perform_regression(Asia_Countries, year)

    print(f"--- Analyse pour l'Europe en l'année {year} ---")
    perform_regression(Europe_countries, year)
    
    print(f"--- Analyse pour le middle east en l'année {year} ---")
    perform_regression(middle_east_central_asia_countries, year)

    print(f"--- Analyse pour l'Afrique en l'année {year} ---")
    perform_regression(sub_saharan_africa_countries, year)

    print(f"--- Analyse pour le western en l'année {year} ---")
    perform_regression(western_hemisphere_countries, year)

# %%
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[4], line 73
#      69     return render_template('dash_app.html')
#      71 # Define a route for rendering the Dash app
#      72 @server.route('/')
# ---> 73 def dash_app():
#      74     return render_template('dash_app.html')
#      76 if __name__ == '__main__':
#
# File ~\anaconda3\lib\site-packages\flask\scaffold.py:449, in Scaffold.route.<locals>.decorator(f)
#     447 def decorator(f: T_route) -> T_route:
#     448     endpoint = options.pop("endpoint", None)
# --> 449     self.add_url_rule(rule, endpoint, f, **options)
#     450     return f
#
# File ~\anaconda3\lib\site-packages\flask\scaffold.py:50, in setupmethod.<locals>.wrapper_func(self, *args, **kwargs)
#      48 def wrapper_func(self, *args: t.Any, **kwargs: t.Any) -> t.Any:
#      49     self._check_setup_finished(f_name)
# ...
